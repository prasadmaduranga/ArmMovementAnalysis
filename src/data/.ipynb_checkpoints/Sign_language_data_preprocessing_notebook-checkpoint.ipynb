# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/features/video/Sign_Language_Data/set1/features_video_test.csv')

# %%
df.shape
# Out:
# (456, 57)

# %%
df.head(5)
# Out:
#             ID  LEFT_WRIST_THUMB_CMC_MCP  LEFT_THUMB_CMC_MCP_IP  \
# 0  050_003_001                       NaN                    NaN
# 1  050_003_001                       NaN                    NaN
# 2  050_003_001                       NaN                    NaN
# 3  050_003_001                       NaN                    NaN
# 4  050_003_001                       NaN                    NaN
#
#    LEFT_THUMB_MCP_IP_TIP  LEFT_WRIST_INDEX_FINGER_MCP_PIP  \
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    NaN                              NaN
# 3                    NaN                              NaN
# 4                    NaN                              NaN
#
#    LEFT_INDEX_FINGER_MCP_PIP_DIP  LEFT_INDEX_FINGER_PIP_DIP_TIP  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    LEFT_WRIST_MIDDLE_FINGER_MCP_PIP  LEFT_MIDDLE_FINGER_MCP_PIP_DIP  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#    LEFT_MIDDLE_FINGER_PIP_DIP_TIP  ...  RIGHT_INDEX_MCP_TIP  \
# 0                             NaN  ...             0.038182
# 1                             NaN  ...             0.037233
# 2                             NaN  ...             0.037994
# 3                             NaN  ...                  NaN
# 4                             NaN  ...             0.037043
#
#    RIGHT_MIDDLE_MCP_TIP  RIGHT_RING_MCP_TIP  RIGHT_PINKY_MCP_TIP  \
# 0              0.039974            0.038502             0.035519
# 1              0.040038            0.037860             0.033885
# 2              0.040267            0.038565             0.035219
# 3                   NaN                 NaN                  NaN
# 4              0.040478            0.038175             0.034676
#
#    RIGHT_THUMB_TIP_INDEX_TIP  RIGHT_INDEX_TIP_MIDDLE_TIP  \
# 0                   0.024175                    0.024823
# 1                   0.019673                    0.023715
# 2                   0.024012                    0.023474
# 3                        NaN                         NaN
# 4                   0.020934                    0.023277
#
#    RIGHT_MIDDLE_TIP_RING_TIP  RIGHT_RING_TIP_PINKY_TIP  L_SHOULDER_L_WRIST  \
# 0                   0.020052                  0.018864            0.681630
# 1                   0.018803                  0.019545            0.399617
# 2                   0.019005                  0.018943            0.419177
# 3                        NaN                       NaN                 NaN
# 4                   0.019403                  0.018894            0.436287
#
#    R_SHOULDER_R_WRIST
# 0            0.578869
# 1            0.346687
# 2            0.379895
# 3                 NaN
# 4            0.351969
#
# [5 rows x 57 columns]

# %%
df.columns
# Out:
# Index(['ID', 'LEFT_WRIST_THUMB_CMC_MCP', 'LEFT_THUMB_CMC_MCP_IP',
#        'LEFT_THUMB_MCP_IP_TIP', 'LEFT_WRIST_INDEX_FINGER_MCP_PIP',
#        'LEFT_INDEX_FINGER_MCP_PIP_DIP', 'LEFT_INDEX_FINGER_PIP_DIP_TIP',
#        'LEFT_WRIST_MIDDLE_FINGER_MCP_PIP', 'LEFT_MIDDLE_FINGER_MCP_PIP_DIP',
#        'LEFT_MIDDLE_FINGER_PIP_DIP_TIP', 'LEFT_WRIST_RING_FINGER_MCP_PIP',
#        'LEFT_RING_FINGER_MCP_PIP_DIP', 'LEFT_RING_FINGER_PIP_DIP_TIP',
#        'LEFT_WRIST_PINKY_MCP_PIP', 'LEFT_PINKY_MCP_PIP_DIP',
#        'LEFT_PINKY_PIP_DIP_TIP', 'RIGHT_WRIST_THUMB_CMC_MCP',
#        'RIGHT_THUMB_CMC_MCP_IP', 'RIGHT_THUMB_MCP_IP_TIP',
#        'RIGHT_WRIST_INDEX_FINGER_MCP_PIP', 'RIGHT_INDEX_FINGER_MCP_PIP_DIP',
#        'RIGHT_INDEX_FINGER_PIP_DIP_TIP', 'RIGHT_WRIST_MIDDLE_FINGER_MCP_PIP',
#        'RIGHT_MIDDLE_FINGER_MCP_PIP_DIP', 'RIGHT_MIDDLE_FINGER_PIP_DIP_TIP',
#        'RIGHT_WRIST_RING_FINGER_MCP_PIP', 'RIGHT_RING_FINGER_MCP_PIP_DIP',
#        'RIGHT_RING_FINGER_PIP_DIP_TIP', 'RIGHT_WRIST_PINKY_MCP_PIP',
#        'RIGHT_PINKY_MCP_PIP_DIP', 'RIGHT_PINKY_PIP_DIP_TIP',
#        'R_SHOULDER_L_SHOULDER_L_ELBOW', 'L_SHOULDER_L_ELBOW_L_WRIST',
#        'L_ELBOW_L_WRIST_L_PINKY', 'L_SHOULDER_R_SHOULDER_R_ELBOW',
#        'R_SHOULDER_R_ELBOW_R_WRIST', 'R_ELBOW_R_WRIST_R_PINKY',
#        'LEFT_THUMB_CMC_TIP', 'LEFT_INDEX_MCP_TIP', 'LEFT_MIDDLE_MCP_TIP',
#        'LEFT_RING_MCP_TIP', 'LEFT_PINKY_MCP_TIP', 'LEFT_THUMB_TIP_INDEX_TIP',
#        'LEFT_INDEX_TIP_MIDDLE_TIP', 'LEFT_MIDDLE_TIP_RING_TIP',
#        'LEFT_RING_TIP_PINKY_TIP', 'RIGHT_THUMB_CMC_TIP', 'RIGHT_INDEX_MCP_TIP',
#        'RIGHT_MIDDLE_MCP_TIP', 'RIGHT_RING_MCP_TIP', 'RIGHT_PINKY_MCP_TIP',
#        'RIGHT_THUMB_TIP_INDEX_TIP', 'RIGHT_INDEX_TIP_MIDDLE_TIP',
#        'RIGHT_MIDDLE_TIP_RING_TIP', 'RIGHT_RING_TIP_PINKY_TIP',
#        'L_SHOULDER_L_WRIST', 'R_SHOULDER_R_WRIST'],
#       dtype='object')

# %%
df.drop(  labels=['LEFT_WRIST_THUMB_CMC_MCP', 'LEFT_THUMB_CMC_MCP_IP',
       'LEFT_THUMB_MCP_IP_TIP', 'LEFT_WRIST_INDEX_FINGER_MCP_PIP',
       'LEFT_INDEX_FINGER_MCP_PIP_DIP', 'LEFT_INDEX_FINGER_PIP_DIP_TIP',
       'LEFT_WRIST_MIDDLE_FINGER_MCP_PIP', 'LEFT_MIDDLE_FINGER_MCP_PIP_DIP',
       'LEFT_MIDDLE_FINGER_PIP_DIP_TIP', 'LEFT_WRIST_RING_FINGER_MCP_PIP',
       'LEFT_RING_FINGER_MCP_PIP_DIP', 'LEFT_RING_FINGER_PIP_DIP_TIP',
       'LEFT_WRIST_PINKY_MCP_PIP', 'LEFT_PINKY_MCP_PIP_DIP',
       'LEFT_PINKY_PIP_DIP_TIP'],
axis=1,
inplace=True
)

# %%
df.drop(  labels=['R_SHOULDER_L_SHOULDER_L_ELBOW', 'L_SHOULDER_L_ELBOW_L_WRIST',
       'L_ELBOW_L_WRIST_L_PINKY','LEFT_THUMB_CMC_TIP', 'LEFT_INDEX_MCP_TIP', 'LEFT_MIDDLE_MCP_TIP',
       'LEFT_RING_MCP_TIP', 'LEFT_PINKY_MCP_TIP', 'LEFT_THUMB_TIP_INDEX_TIP',
       'LEFT_INDEX_TIP_MIDDLE_TIP', 'LEFT_MIDDLE_TIP_RING_TIP',
       'LEFT_RING_TIP_PINKY_TIP','L_SHOULDER_L_WRIST'],
axis=1,
inplace=True
)

# %%
df.head(5)
# Out:
#             ID  RIGHT_WRIST_THUMB_CMC_MCP  RIGHT_THUMB_CMC_MCP_IP  \
# 0  050_003_001                     170.90                  134.26
# 1  050_003_001                     167.93                  128.23
# 2  050_003_001                     170.41                  132.85
# 3  050_003_001                        NaN                     NaN
# 4  050_003_001                     166.60                  134.75
#
#    RIGHT_THUMB_MCP_IP_TIP  RIGHT_WRIST_INDEX_FINGER_MCP_PIP  \
# 0                  156.14                             56.47
# 1                  145.11                             54.58
# 2                  158.36                             57.03
# 3                     NaN                               NaN
# 4                  159.65                             56.63
#
#    RIGHT_INDEX_FINGER_MCP_PIP_DIP  RIGHT_INDEX_FINGER_PIP_DIP_TIP  \
# 0                          143.54                           70.21
# 1                          140.41                           67.27
# 2                          141.44                           70.31
# 3                             NaN                             NaN
# 4                          136.32                           66.75
#
#    RIGHT_WRIST_MIDDLE_FINGER_MCP_PIP  RIGHT_MIDDLE_FINGER_MCP_PIP_DIP  \
# 0                              52.98                           127.35
# 1                              51.39                           127.23
# 2                              53.15                           127.19
# 3                                NaN                              NaN
# 4                              54.04                           124.87
#
#    RIGHT_MIDDLE_FINGER_PIP_DIP_TIP  ...  RIGHT_THUMB_CMC_TIP  \
# 0                            56.43  ...             0.043720
# 1                            55.79  ...             0.037205
# 2                            60.29  ...             0.041847
# 3                              NaN  ...                  NaN
# 4                            57.24  ...             0.039836
#
#    RIGHT_INDEX_MCP_TIP  RIGHT_MIDDLE_MCP_TIP  RIGHT_RING_MCP_TIP  \
# 0             0.038182              0.039974            0.038502
# 1             0.037233              0.040038            0.037860
# 2             0.037994              0.040267            0.038565
# 3                  NaN                   NaN                 NaN
# 4             0.037043              0.040478            0.038175
#
#    RIGHT_PINKY_MCP_TIP  RIGHT_THUMB_TIP_INDEX_TIP  RIGHT_INDEX_TIP_MIDDLE_TIP  \
# 0             0.035519                   0.024175                    0.024823
# 1             0.033885                   0.019673                    0.023715
# 2             0.035219                   0.024012                    0.023474
# 3                  NaN                        NaN                         NaN
# 4             0.034676                   0.020934                    0.023277
#
#    RIGHT_MIDDLE_TIP_RING_TIP  RIGHT_RING_TIP_PINKY_TIP  R_SHOULDER_R_WRIST
# 0                   0.020052                  0.018864            0.578869
# 1                   0.018803                  0.019545            0.346687
# 2                   0.019005                  0.018943            0.379895
# 3                        NaN                       NaN                 NaN
# 4                   0.019403                  0.018894            0.351969
#
# [5 rows x 29 columns]

# %%
df.isna().sum()
# Out:
# ID                                     0
# RIGHT_WRIST_THUMB_CMC_MCP            149
# RIGHT_THUMB_CMC_MCP_IP               149
# RIGHT_THUMB_MCP_IP_TIP               149
# RIGHT_WRIST_INDEX_FINGER_MCP_PIP     149
# RIGHT_INDEX_FINGER_MCP_PIP_DIP       149
# RIGHT_INDEX_FINGER_PIP_DIP_TIP       149
# RIGHT_WRIST_MIDDLE_FINGER_MCP_PIP    149
# RIGHT_MIDDLE_FINGER_MCP_PIP_DIP      149
# RIGHT_MIDDLE_FINGER_PIP_DIP_TIP      149
# RIGHT_WRIST_RING_FINGER_MCP_PIP      149
# RIGHT_RING_FINGER_MCP_PIP_DIP        149
# RIGHT_RING_FINGER_PIP_DIP_TIP        149
# RIGHT_WRIST_PINKY_MCP_PIP            149
# RIGHT_PINKY_MCP_PIP_DIP              149
# RIGHT_PINKY_PIP_DIP_TIP              149
# L_SHOULDER_R_SHOULDER_R_ELBOW        349
# R_SHOULDER_R_ELBOW_R_WRIST           389
# R_ELBOW_R_WRIST_R_PINKY              389
# RIGHT_THUMB_CMC_TIP                  149
# RIGHT_INDEX_MCP_TIP                  149
# RIGHT_MIDDLE_MCP_TIP                 149
# RIGHT_RING_MCP_TIP                   149
# RIGHT_PINKY_MCP_TIP                  149
# RIGHT_THUMB_TIP_INDEX_TIP            149
# RIGHT_INDEX_TIP_MIDDLE_TIP           149
# RIGHT_MIDDLE_TIP_RING_TIP            149
# RIGHT_RING_TIP_PINKY_TIP             149
# R_SHOULDER_R_WRIST                   243
# dtype: int64

# %%
df.shape
# Out:
# (456, 29)
